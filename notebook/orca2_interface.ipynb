# %%
# Out:
# config.json: 100%|██████████| 582/582 [00:00<?, ?B/s]
# pytorch_model.bin.index.json: 100%|██████████| 23.9k/23.9k [00:00<00:00, 5.88MB/s]
# pytorch_model-00001-of-00003.bin:  82%|████████▏ | 8.12G/9.88G [12:53<02:47, 10.5MB/s]
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\david\OneDrive\Documenti\GitHub\AI-PROJECT\notebook\orca2_interface.ipynb Cell 1 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/david/OneDrive/Documenti/GitHub/AI-PROJECT/notebook/orca2_interface.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> else:
#       <a href='vscode-notebook-cell:/c%3A/Users/david/OneDrive/Documenti/GitHub/AI-PROJECT/notebook/orca2_interface.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a>     torch.set_default_device("cpu")
# ...
